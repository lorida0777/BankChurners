# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plta
import seaborn as sns

# %%
df = pd.read_csv('BankChurners.csv')

# %%
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School            NaN  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0              39  ...                       1                      3
# ...

# %%
df.describe()
# Out:
#           CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count  1.012700e+04  10127.000000     10127.000000    10127.000000
# mean   7.391776e+08     46.325960         2.346203       35.928409
# std    3.690378e+07      8.016814         1.298908        7.986416
# min    7.080821e+08     26.000000         0.000000       13.000000
# 25%    7.130368e+08     41.000000         1.000000       31.000000
# 50%    7.179264e+08     46.000000         2.000000       36.000000
# 75%    7.731435e+08     52.000000         3.000000       40.000000
# max    8.283431e+08     73.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count              10127.000000            10127.000000
# mean                   3.812580                2.341167
# std                    1.554408                1.010622
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CLIENTNUM                 10127 non-null  int64
#  1   Attrition_Flag            10127 non-null  object
#  2   Customer_Age              10127 non-null  int64
#  3   Gender                    10127 non-null  object
#  4   Dependent_count           10127 non-null  int64
#  5   Education_Level           8608 non-null   object
#  6   Marital_Status            9378 non-null   object
#  7   Income_Category           10127 non-null  object
#  8   Card_Category             10127 non-null  object
#  9   Months_on_book            10127 non-null  int64
#  10  Total_Relationship_Count  10127 non-null  int64
#  11  Months_Inactive_12_mon    10127 non-null  int64
#  12  Contacts_Count_12_mon     10127 non-null  int64
# ...

# %%
df.isna().sum()
# Out:
# CLIENTNUM                      0
# Attrition_Flag                 0
# Customer_Age                   0
# Gender                         0
# Dependent_count                0
# Education_Level             1519
# Marital_Status               749
# Income_Category                0
# Card_Category                  0
# Months_on_book                 0
# Total_Relationship_Count       0
# Months_Inactive_12_mon         0
# Contacts_Count_12_mon          0
# Credit_Limit                   0
# Total_Revolving_Bal            0
# Avg_Open_To_Buy                0
# Total_Amt_Chng_Q4_Q1           0
# Total_Trans_Amt                0
# Total_Trans_Ct                 0
# Total_Ct_Chng_Q4_Q1            0
# Avg_Utilization_Ratio          0
# dtype: int64

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7973 entries, 0 to 10126
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CLIENTNUM                 7973 non-null   int64
#  1   Attrition_Flag            7973 non-null   object
#  2   Customer_Age              7973 non-null   int64
#  3   Gender                    7973 non-null   object
#  4   Dependent_count           7973 non-null   int64
#  5   Education_Level           7973 non-null   object
#  6   Marital_Status            7973 non-null   object
#  7   Income_Category           7973 non-null   object
#  8   Card_Category             7973 non-null   object
#  9   Months_on_book            7973 non-null   int64
#  10  Total_Relationship_Count  7973 non-null   int64
#  11  Months_Inactive_12_mon    7973 non-null   int64
#  12  Contacts_Count_12_mon     7973 non-null   int64
#  13  Credit_Limit              7973 non-null   float64
# ...

# %%
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 4  709106358  Existing Customer            40      M                3
# 5  713061558  Existing Customer            44      M                2
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
# 5        Graduate        Married     $40K - $60K          Blue
#
#    Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0              39  ...                       1                      3
# ...

# %%
df['Gender'].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
df['Income_Category'].unique()
# Out:
# array(['$60K - $80K', 'Less than $40K', '$80K - $120K', '$40K - $60K',
#        'abc', '$120K +'], dtype=object)

# %%
df = df[df['Income_Category']!='abc']

# %%
df['Income_Category'].unique()
# Out:
# array(['$60K - $80K', 'Less than $40K', '$80K - $120K', '$40K - $60K',
#        '$120K +'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7081 entries, 0 to 10126
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CLIENTNUM                 7081 non-null   int64
#  1   Attrition_Flag            7081 non-null   object
#  2   Customer_Age              7081 non-null   int64
#  3   Gender                    7081 non-null   object
#  4   Dependent_count           7081 non-null   int64
#  5   Education_Level           7081 non-null   object
#  6   Marital_Status            7081 non-null   object
#  7   Income_Category           7081 non-null   object
#  8   Card_Category             7081 non-null   object
#  9   Months_on_book            7081 non-null   int64
#  10  Total_Relationship_Count  7081 non-null   int64
#  11  Months_Inactive_12_mon    7081 non-null   int64
#  12  Contacts_Count_12_mon     7081 non-null   int64
#  13  Credit_Limit              7081 non-null   float64
# ...

# %%
df['Attrition_Flag'].unique()
# Out:
# array(['Existing Customer', 'Attrited Customer'], dtype=object)

# %%
df['Marital_Status'].unique()
# Out:
# array(['Married', 'Single', 'Divorced'], dtype=object)

# %%
df['Card_Category'].unique()
# Out:
# array(['Blue', 'Gold', 'Silver', 'Platinum'], dtype=object)

# %%
sns.countplot(x='Income_Category', data=df, palette='Dark2')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_21016\4210849438.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Income_Category', data=df, palette='Dark2')
# <Axes: xlabel='Income_Category', ylabel='count'>

# %%
# Ne garder que les colonnes numériques
corr = df.select_dtypes(include=[np.number]).corr()

# Heatmap
plt.figure(figsize=(9, 9))
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm", square=True)
plt.title("Carte de chaleur des corrélations")
plt.show()

# %%
cor = pd.get_dummies(df)
correlation = cor.corr()
plt.figure(figsize=(30, 20))
sns.heatmap(correlation, annot=True)
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7081 entries, 0 to 10126
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Attrition_Flag            7081 non-null   object
#  1   Customer_Age              7081 non-null   int64
#  2   Gender                    7081 non-null   object
#  3   Dependent_count           7081 non-null   int64
#  4   Income_Category           7081 non-null   object
#  5   Card_Category             7081 non-null   object
#  6   Total_Relationship_Count  7081 non-null   int64
#  7   Months_Inactive_12_mon    7081 non-null   int64
#  8   Contacts_Count_12_mon     7081 non-null   int64
#  9   Credit_Limit              7081 non-null   float64
#  10  Total_Revolving_Bal       7081 non-null   int64
#  11  Avg_Open_To_Buy           7081 non-null   float64
#  12  Total_Amt_Chng_Q4_Q1      7081 non-null   float64
#  13  Total_Trans_Amt           7081 non-null   int64
# ...

# %%
# df = pd.read_csv('BankChurners.csv')
no_corr= ['CLIENTNUM','Education_Level', 'Months_on_book', 'Marital_Status']
df = df.drop(no_corr, axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7081 entries, 0 to 10126
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Attrition_Flag            7081 non-null   object
#  1   Customer_Age              7081 non-null   int64
#  2   Gender                    7081 non-null   object
#  3   Dependent_count           7081 non-null   int64
#  4   Income_Category           7081 non-null   object
#  5   Card_Category             7081 non-null   object
#  6   Total_Relationship_Count  7081 non-null   int64
#  7   Months_Inactive_12_mon    7081 non-null   int64
#  8   Contacts_Count_12_mon     7081 non-null   int64
#  9   Credit_Limit              7081 non-null   float64
#  10  Total_Revolving_Bal       7081 non-null   int64
#  11  Avg_Open_To_Buy           7081 non-null   float64
#  12  Total_Amt_Chng_Q4_Q1      7081 non-null   float64
#  13  Total_Trans_Amt           7081 non-null   int64
# ...

# %%
df.head()
# Out:
#       Attrition_Flag  Customer_Age Gender  Dependent_count Income_Category  \
# 0  Existing Customer            45      M                3     $60K - $80K
# 1  Existing Customer            49      F                5  Less than $40K
# 2  Existing Customer            51      M                3    $80K - $120K
# 4  Existing Customer            40      M                3     $60K - $80K
# 5  Existing Customer            44      M                2     $40K - $60K
#
#   Card_Category  Total_Relationship_Count  Months_Inactive_12_mon  \
# 0          Blue                         5                       1
# 1          Blue                         6                       1
# 2          Blue                         4                       1
# 4          Blue                         5                       1
# 5          Blue                         3                       1
#
#    Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# ...

# %%
#Séparation des variables indépendantes (X) et dépendante(y)
X= df.drop('Attrition_Flag', axis=1)
y = df['Attrition_Flag']
X.select_dtypes(include='object').columns
# Out:
# Index(['Gender', 'Income_Category', 'Card_Category'], dtype='object')

# %%
X = pd.get_dummies(X, drop_first=True)  # ou drop_first=False selon le besoin

# %%
# Bibliothèque necessaire
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import StandardScaler

# # Étapes :
# X = pd.get_dummies(X, drop_first=True)

# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# scaler = StandardScaler()
# scaled_X_train = scaler.fit_transform(X_train)
# scaled_X_test = scaler.transform(X_test)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)
#Normalisation des données avec StandardScaler
scaler = StandardScaler()
scaled_X_train = scaler.fit_transform(X_train)
scaled_X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.linear_model import LogisticRegressionCV

# %%
log_model = LogisticRegression()

# %%
log_model.fit(scaled_X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = log_model.predict(scaled_X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, ConfusionMatrixDisplay

# %%
penalty = ['l1', 'l2']

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9054340155257586

# %%
# Confusion matrix
confusion_matrix(y_test,y_pred)
# Out:
# array([[ 122,   96],
#        [  38, 1161]], dtype=int64)

# %%
# À partir du modèle lui-même
ConfusionMatrixDisplay.from_estimator(log_model,scaled_X_test,y_test);
